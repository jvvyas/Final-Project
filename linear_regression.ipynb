# %% [markdown]
# # Linear Regression Models
#
# Our team created three linear regression models to predict U.S. counties' estimated hesitant, hesitant or unsure, and strongly hesistant rates, respectively, based on 25 features.
#
# -----------------------------
# ### **Feature Groups**
#
# **Vaccine Availability:**
# 1. `the_number_of_providers` per FIPS code
# 2. `the_average_supply_level` for all location providers per FIPS code
#
# **Community Risk/Vaccination Measures:**
#
# 3. `social_vulnerability_index_svi` ranges from 0 (least) to 1 (most) to measure community's vulnerability to disaster
# 4. `cvac_level_of_concern_for_vaccination_rollout` ranges from 0 (lowest) to 1 (highest) for concern for difficult vaccine rollout
# 5. `percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21`
# 6. `community_transmission_level` is either low, moderate, substantial, or high rate of transmission:
# * based on total new COVID-19 cases per 100,000 persons in the last 7 days and percentage of positive SARS-CoV-2 diagnostic nucleic acid amplification tests (NAAT) in the last 7 days (higher of the two if different)
# 7. `series_complete_pop_pct` tells percent of people fully vaccinated
#
# **Orders/Bans and Other Guidance:**
#
# 8. `masks_order_code`where 1 = public mask mandate; 2 = no public mask mandate
# 9. `general_gb_order_code` indicates size of gatherings banned:
# * 1 = No order (for gathering ban) found
# * 6 = Ban of gatherings over 1-10 people
# * 4 = Ban of gatherings over 26-50 people
# * 2 = Ban of gatherings over 101 or more people
# * 7 = Bans gatherings of any size
# 10. `general_or_under_6ft_bans_gatherings_over` tells max number of people that can gather without social distancing:
# * No ban, 0, 6, 8, 10, 50, 150, or 250
# 11. `stay_at_home_order_code` based on stay at home order recommendation:
# * 7 = No order for individuals to stay home or NA
# * 6 = Advisory/Recommendation
# * 3 = Mandatory only for at-risk individuals in the jurisdiction
#
# **Health Conditions** (county average estimates of prevalence of specified health conditions in adults 2019):
#
# 12. `avg_asthma`
# 13. `avg_chd` (coronary heart disease)
# 14. `avg_checkup`
# 15. `avg_copd` (chronic obstructive pulmonary disease)
# 16. `avg_smoking`
# 17. `avg_depression`
# 18. `avg_diabetes`
# 19. `avg_ghlth` for fair or poor health
# 20. `avg_lpa` for no leisure-time physical activity
# 21. `avg_mhlth` for mental health not good for >=14 days
# 22. `avg_obesity`
# 23. `avg_sleep` for sleeping less than 7 hours
#
# **Other:**
#
# 24. `fips_code` is Federal Information Processing Standards (FIPS) Code; unique to each county
# 25. `metro_status` for metro (metropolitan county) vs non-metro

# %% [markdown]
# # Clean Data:

# %%
# import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# load file
df = pd.read_csv(Path('Resources/(new)joined_8_tables_on_county_level.csv'))
df
# Out:
#       county_fips_code  the_number_of_providers  the_average_supply_level  \
# 0                10001                      195                  0.333333
# 1                10003                      638                  0.194357
# 2                10005                      295                  0.196610
# 3                11001                      678                  0.244838
# 4                12001                      345                  0.382609
# ...                ...                      ...                       ...
# 2616             56037                       39                  0.102564
# 2617             56039                       15                  0.000000
# 2618             56041                       33                 -0.090909
# 2619             56043                        7                 -0.714286
# 2620             56045                       12                 -0.500000
#
#       fips_code                                 county_name  \
# 0         10001                       Kent County, Delaware
# 1         10003                 New Castle County, Delaware
# 2         10005                     Sussex County, Delaware
# 3         11001  District of Columbia, District of Columbia
# 4         12001                     Alachua County, Florida
# ...         ...                                         ...
# 2616      56037                  Sweetwater County, Wyoming
# 2617      56039                       Teton County, Wyoming
# 2618      56041                       Uinta County, Wyoming
# 2619      56043                    Washakie County, Wyoming
# 2620      56045                      Weston County, Wyoming
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  ...  avg_checkup  \
# 0                 0.0664                        0.1391  ...    80.593750
# 1                 0.0564                        0.1180  ...    79.198450
# 2                 0.0555                        0.1121  ...    81.164151
# 3                 0.0655                        0.0850  ...    79.094944
# 4                 0.1167                        0.1711  ...    76.055357
# ...                  ...                           ...  ...          ...
# 2616              0.2184                        0.2843  ...    65.275000
# 2617              0.2050                        0.2671  ...    65.425000
# 2618              0.2184                        0.2843  ...    63.466667
# 2619              0.2283                        0.2943  ...    66.966667
# 2620              0.2283                        0.2943  ...    67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 37 columns]

# %%
df.dtypes
# Out:
# county_fips_code                                                    int64
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# county_name                                                        object
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# completeness_pct                                                  float64
# metro_status                                                       object
# series_complete_pop_pct                                           float64
# series_complete_yes                                               float64
# series_complete_pop_pct_svi                                       float64
# series_complete_pop_pct_ur_equity                                 float64
# general_gb_order_code                                               int64
# general_gb_order_group                                             object
# general_or_under_6ft_bans_gatherings_over                          object
# indoor_outdoor                                                    float64
# stay_at_home_order_code                                             int64
# community_transmission_level                                       object
# cases_per_100k_7_day_count_change                                  object
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %%
# drop redundant columns
df = df.drop(['county_fips_code', 'county_name', 'indoor_outdoor', 'completeness_pct', 'series_complete_yes', 'series_complete_pop_pct_svi', 'series_complete_pop_pct_ur_equity', 'general_gb_order_group', 'cases_per_100k_7_day_count_change'], axis=1)
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ... avg_checkup  \
# 0                          0.0388                 2  ...   80.593750
# 1                          0.0329                 2  ...   79.198450
# 2                          0.0328                 2  ...   81.164151
# 3                          0.0403                 2  ...   79.094944
# 4                          0.0755                 2  ...   76.055357
# ...                           ...               ...  ...         ...
# 2616                       0.1584                 2  ...   65.275000
# 2617                       0.1472                 2  ...   65.425000
# 2618                       0.1584                 2  ...   63.466667
# 2619                       0.1687                 2  ...   66.966667
# 2620                       0.1687                 2  ...   67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 28 columns]

# %%
## check total nulls per column
df.isnull().sum()
# Out:
# the_number_of_providers                                             0
# the_average_supply_level                                            0
# fips_code                                                           0
# social_vulnerability_index_svi                                      1
# cvac_level_of_concern_for_vaccination_rollout                       0
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    214
# estimated_hesitant                                                  0
# estimated_hesitant_or_unsure                                        0
# estimated_strongly_hesitant                                         0
# masks_order_code                                                    0
# metro_status                                                        0
# series_complete_pop_pct                                             7
# general_gb_order_code                                               0
# general_or_under_6ft_bans_gatherings_over                         201
# stay_at_home_order_code                                             0
# community_transmission_level                                        0
# avg_asthma                                                         21
# avg_chd                                                            21
# avg_checkup                                                        21
# avg_copd                                                           21
# avg_smoking                                                        21
# avg_depression                                                     21
# avg_diabetes                                                       21
# avg_ghlth                                                          21
# avg_lpa                                                            21
# avg_mhlth                                                          21
# avg_obesity                                                        21
# avg_sleep                                                           0
# dtype: int64

# %%
# fill nulls: since 'percent_adults_fully_vaccinated' is continous data, fill with mean values (Mean Completer)
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(missing_values = np.NaN, strategy='mean',add_indicator=True)
mode_imputer = SimpleImputer(missing_values = np.NaN, strategy='most_frequent', add_indicator=True)

vaccine_series = mean_imputer.fit_transform(np.array(df['percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21']).reshape(-1,1))

df['percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21'] = np.array(vaccine_series)
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ... avg_checkup  \
# 0                          0.0388                 2  ...   80.593750
# 1                          0.0329                 2  ...   79.198450
# 2                          0.0328                 2  ...   81.164151
# 3                          0.0403                 2  ...   79.094944
# 4                          0.0755                 2  ...   76.055357
# ...                           ...               ...  ...         ...
# 2616                       0.1584                 2  ...   65.275000
# 2617                       0.1472                 2  ...   65.425000
# 2618                       0.1584                 2  ...   63.466667
# 2619                       0.1687                 2  ...   66.966667
# 2620                       0.1687                 2  ...   67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 28 columns]

# %%
## check total nulls per column
df.isnull().sum()
# Out:
# the_number_of_providers                                             0
# the_average_supply_level                                            0
# fips_code                                                           0
# social_vulnerability_index_svi                                      1
# cvac_level_of_concern_for_vaccination_rollout                       0
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21      0
# estimated_hesitant                                                  0
# estimated_hesitant_or_unsure                                        0
# estimated_strongly_hesitant                                         0
# masks_order_code                                                    0
# metro_status                                                        0
# series_complete_pop_pct                                             7
# general_gb_order_code                                               0
# general_or_under_6ft_bans_gatherings_over                         201
# stay_at_home_order_code                                             0
# community_transmission_level                                        0
# avg_asthma                                                         21
# avg_chd                                                            21
# avg_checkup                                                        21
# avg_copd                                                           21
# avg_smoking                                                        21
# avg_depression                                                     21
# avg_diabetes                                                       21
# avg_ghlth                                                          21
# avg_lpa                                                            21
# avg_mhlth                                                          21
# avg_obesity                                                        21
# avg_sleep                                                           0
# dtype: int64

# %%
# drop nulls
df = df.dropna()
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ... avg_checkup  \
# 0                          0.0388                 2  ...   80.593750
# 1                          0.0329                 2  ...   79.198450
# 2                          0.0328                 2  ...   81.164151
# 3                          0.0403                 2  ...   79.094944
# 4                          0.0755                 2  ...   76.055357
# ...                           ...               ...  ...         ...
# 2616                       0.1584                 2  ...   65.275000
# 2617                       0.1472                 2  ...   65.425000
# 2618                       0.1584                 2  ...   63.466667
# 2619                       0.1687                 2  ...   66.966667
# 2620                       0.1687                 2  ...   67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2391 rows x 28 columns]

# %% [markdown]
# ##### 440 rows dropped; we do not believe this will have a huge impact on our data given the abundance of data remaining

# %% [markdown]
# # Pre-process/Encode Data:

# %%
# view data types
df.dtypes
# Out:
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# metro_status                                                       object
# series_complete_pop_pct                                           float64
# general_gb_order_code                                               int64
# general_or_under_6ft_bans_gatherings_over                          object
# stay_at_home_order_code                                             int64
# community_transmission_level                                       object
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %%
# show columns with object data types and their unique values count
df_cols_to_encode = df.dtypes[df.dtypes == 'object'].index
df[df_cols_to_encode].nunique()
# Out:
# metro_status                                 2
# general_or_under_6ft_bans_gatherings_over    8
# community_transmission_level                 4
# dtype: int64

# %%
# print unique values in object columns
for i in df_cols_to_encode:
    print(f"{i}: {df[i].unique()}\n")
# Out:
# metro_status: ['Metro' 'Non-metro']
#
# general_or_under_6ft_bans_gatherings_over: ['No ban' '50' '150' '250' '10' '6' '8' '0']
#
# community_transmission_level: ['moderate' 'low' 'substantial' 'high']

# %%
# label encoder for object type columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_new = df.copy()
df_new['metro_status'] = le.fit_transform(df_new['metro_status'])
df_new['general_or_under_6ft_bans_gatherings_over'] = le.fit_transform(df_new['general_or_under_6ft_bans_gatherings_over'])
df_new['community_transmission_level'] = le.fit_transform(df_new['community_transmission_level'])
df_new
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ...  avg_checkup  \
# 0                          0.0388                 2  ...    80.593750
# 1                          0.0329                 2  ...    79.198450
# 2                          0.0328                 2  ...    81.164151
# 3                          0.0403                 2  ...    79.094944
# 4                          0.0755                 2  ...    76.055357
# ...                           ...               ...  ...          ...
# 2616                       0.1584                 2  ...    65.275000
# 2617                       0.1472                 2  ...    65.425000
# 2618                       0.1584                 2  ...    63.466667
# 2619                       0.1687                 2  ...    66.966667
# 2620                       0.1687                 2  ...    67.300000
#
#       avg_copd  avg_smoking  avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875       20.575000     12.378125  20.303125
# 1     7.067442    16.818605       20.256589     10.819380  18.208527
# 2     9.215094    16.686792       18.324528     12.662264  19.600000
# 3     4.977528    15.800000       20.562921      9.938202  16.479775
# 4     7.030357    16.417857       21.016071      9.007143  17.764286
# ...        ...          ...             ...           ...        ...
# 2616  5.983333    18.658333       19.225000      7.541667  15.700000
# 2617  4.425000    12.175000       16.825000      6.025000  10.950000
# 2618  7.200000    20.266667       19.833333      8.066667  17.100000
# 2619  8.033333    18.133333       18.000000     10.433333  18.466667
# 2620  8.000000    19.250000       18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2391 rows x 28 columns]

# %%
df_new.dtypes
# Out:
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# metro_status                                                        int32
# series_complete_pop_pct                                           float64
# general_gb_order_code                                               int64
# general_or_under_6ft_bans_gatherings_over                           int32
# stay_at_home_order_code                                             int64
# community_transmission_level                                        int32
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %% [markdown]
# # Define Features Set and Three Targets:

# %%
# define features set used for all three targets
X = df_new.copy()
X = X.drop(['estimated_hesitant', 'estimated_hesitant_or_unsure', 'estimated_strongly_hesitant'], axis=1)
X.head()
# Out:
#    the_number_of_providers  the_average_supply_level  fips_code  \
# 0                      195                  0.333333      10001
# 1                      638                  0.194357      10003
# 2                      295                  0.196610      10005
# 3                      678                  0.244838      11001
# 4                      345                  0.382609      12001
#
#    social_vulnerability_index_svi  \
# 0                            0.73
# 1                            0.38
# 2                            0.40
# 3                            0.60
# 4                            0.47
#
#    cvac_level_of_concern_for_vaccination_rollout  \
# 0                                           0.32
# 1                                           0.16
# 2                                           0.12
# 3                                           0.17
# 4                                           0.63
#
#    percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                              0.435
# 1                                              0.552
# 2                                              0.569
# 3                                              0.546
# 4                                              0.547
#
#    masks_order_code  metro_status  series_complete_pop_pct  \
# 0                 2             0                     34.9
# 1                 2             0                     45.5
# 2                 2             0                     47.6
# 3                 2             0                     46.5
# 4                 2             0                     46.6
#
#    general_gb_order_code  ...  avg_checkup  avg_copd  avg_smoking  \
# 0                      1  ...    80.593750  8.821875    19.321875
# 1                      1  ...    79.198450  7.067442    16.818605
# 2                      1  ...    81.164151  9.215094    16.686792
# 3                      1  ...    79.094944  4.977528    15.800000
# 4                      1  ...    76.055357  7.030357    16.417857
#
#    avg_depression  avg_diabetes  avg_ghlth    avg_lpa  avg_mhlth  avg_obesity  \
# 0       20.575000     12.378125  20.303125  31.053125  16.381250    40.696875
# 1       20.256589     10.819380  18.208527  27.695349  14.471318    33.551938
# 2       18.324528     12.662264  19.600000  27.286792  13.303774    34.924528
# 3       20.562921      9.938202  16.479775  20.893820  13.581461    28.410112
# 4       21.016071      9.007143  17.764286  24.160714  17.630357    30.223214
#
#    avg_sleep
# 0  38.543750
# 1  36.662791
# 2  33.426415
# 3  37.917978
# 4  35.637500
#
# [5 rows x 25 columns]

# %%
# set target for each model
hes_y = df_new['estimated_hesitant']

hes_unsure_y = df_new['estimated_hesitant_or_unsure']

strg_hes_y = df_new['estimated_strongly_hesitant']

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Hesitant

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    hes_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1793, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.15746501, 0.12209818, 0.14599018, 0.10012311, 0.08334795,
#        0.12326321, 0.14624001, 0.09732415, 0.1287034 , 0.11222926,
#        0.0622016 , 0.13122898, 0.14809121, 0.12921727, 0.17486518,
#        0.13639113, 0.13946812, 0.08231533, 0.15532882, 0.13031898,
#        0.11185762, 0.08242689, 0.11780875, 0.09998068, 0.11027831,
#        0.1335816 , 0.1282838 , 0.09477465, 0.12903443, 0.12860962,
#        0.10260331, 0.16421472, 0.08679773, 0.12635427, 0.10224537,
#        0.18383562, 0.13503997, 0.07917969, 0.11906953, 0.11737223,
#        0.16267667, 0.18678594, 0.1503613 , 0.12262256, 0.12731231,
#        0.15560804, 0.09716048, 0.12331839, 0.12386725, 0.17759314,
#        0.16062532, 0.11404845, 0.08779591, 0.12247822, 0.12734013,
#        0.1715175 , 0.09363228, 0.18303104, 0.11090096, 0.12947047,
#        0.17885431, 0.11110427, 0.08649926, 0.11873854, 0.13731168,
#        0.17753192, 0.12337586, 0.15937838, 0.13095125, 0.09490221,
#        0.14806064, 0.08618616, 0.11661121, 0.17596452, 0.12981438,
#        0.18038655, 0.09054419, 0.12752354, 0.11872636, 0.05014588,
#        0.08418289, 0.07740179, 0.09860798, 0.12469848, 0.16551216,
#        0.11724876, 0.09826278, 0.0840504 , 0.10620082, 0.14437188,
#        0.17496371, 0.12898078, 0.10911236, 0.13240794, 0.12441778,
#        0.11393441, 0.12008648, 0.14092373, 0.16921759, 0.15638192,
#        0.12534763, 0.15131192, 0.09680932, 0.13376326, 0.12493177,
#        0.11330128, 0.13219681, 0.15337607, 0.15412179, 0.1739981 ,
#        0.15253144, 0.13787591, 0.14201738, 0.13910941, 0.23803655,
#        0.09548959, 0.15761843, 0.09728493, 0.11431708, 0.15104517,
#        0.15614861, 0.16371068, 0.19082651, 0.07705844, 0.1408853 ,
#        0.13631706, 0.15206628, 0.11059529, 0.10570232, 0.14260821,
#        0.1435229 , 0.13018999, 0.13032684, 0.13866194, 0.12861965,
#        0.18088304, 0.04865221, 0.11826156, 0.11899255, 0.10480978,
#        0.10858819, 0.10534512, 0.10914139, 0.06658352, 0.14957386,
#        0.15140827, 0.1221237 , 0.11253236, 0.12065197, 0.13105576,
#        0.09215386, 0.14420996, 0.15079671, 0.13989248, 0.09049984,
#        0.13979548, 0.12823706, 0.06620826, 0.14780352, 0.04051924,
#        0.1758204 , 0.11931291, 0.15541438, 0.1348305 , 0.08738487,
#        0.1086246 , 0.15147004, 0.08317808, 0.17889369, 0.14623944,
#        0.13294365, 0.16661812, 0.12166942, 0.17738522, 0.15729001,
#        0.17030547, 0.10377845, 0.14691747, 0.17172205, 0.11070008,
#        0.17497879, 0.20140262, 0.13023778, 0.07619865, 0.12210417,
#        0.07704164, 0.15386923, 0.18696689])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Hesitant\n")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Hesitant
#
# R2 Score : 0.5616565516951978

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Hesitant or Unsure

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    hes_unsure_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1793, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.20143881, 0.18675944, 0.21511788, 0.15056862, 0.12374592,
#        0.18020279, 0.21549734, 0.17115735, 0.17914885, 0.16369924,
#        0.11806718, 0.1724288 , 0.20332604, 0.18252733, 0.24026443,
#        0.20242539, 0.19720798, 0.13967956, 0.2091245 , 0.18244383,
#        0.18070525, 0.153656  , 0.16478062, 0.15233761, 0.16532708,
#        0.19332082, 0.17856427, 0.17644316, 0.19618939, 0.16659549,
#        0.14708906, 0.21864617, 0.13973277, 0.18847961, 0.16774575,
#        0.16519638, 0.17728568, 0.20140534, 0.15830655, 0.20874873,
#        0.23935198, 0.18589807, 0.17122641, 0.21767215, 0.21219575,
#        0.22538533, 0.17122398, 0.23883336, 0.23149992, 0.21019558,
#        0.17287178, 0.2172189 , 0.23271448, 0.17634054, 0.20868169,
#        0.20112632, 0.17258849, 0.10928357, 0.23173806, 0.17017788,
#        0.18114477, 0.14310236, 0.20600898, 0.18524346, 0.18491273,
#        0.20932304, 0.13951303, 0.16902937, 0.22160797, 0.19202238,
#        0.24688954, 0.1510868 , 0.19877043, 0.18383835, 0.09485443,
#        0.13732957, 0.13025608, 0.15420701, 0.17599792, 0.22784406,
#        0.17346781, 0.14950997, 0.12120139, 0.18310768, 0.22581216,
#        0.2384461 , 0.19069324, 0.17575596, 0.18872892, 0.18644082,
#        0.16215822, 0.17942081, 0.19755114, 0.22793749, 0.2106238 ,
#        0.21908443, 0.2150073 , 0.15583378, 0.18238068, 0.1922185 ,
#        0.16932277, 0.18631964, 0.20373282, 0.22390736, 0.23564994,
#        0.21876809, 0.18637652, 0.20988652, 0.19368506, 0.30066985,
#        0.14419286, 0.25313594, 0.17464948, 0.16040825, 0.20398838,
#        0.21079056, 0.21801878, 0.25200187, 0.11563472, 0.1975779 ,
#        0.18700925, 0.22223951, 0.165211  , 0.16127937, 0.20420985,
#        0.20316644, 0.19409884, 0.17335177, 0.19577325, 0.18131279,
#        0.25078038, 0.0912277 , 0.17731358, 0.18204616, 0.1774216 ,
#        0.15308794, 0.18058007, 0.16203793, 0.12222236, 0.21497065,
#        0.21201116, 0.17056258, 0.16314959, 0.18861338, 0.18726117,
#        0.14973213, 0.21127814, 0.20130749, 0.19648079, 0.14316914,
#        0.21222361, 0.19712092, 0.10740235, 0.1973628 , 0.08067278,
#        0.2407546 , 0.16792639, 0.23940191, 0.20733902, 0.14178132,
#        0.16616969, 0.20709981, 0.14526774, 0.25396442, 0.21440686,
#        0.18656455, 0.23393244, 0.15541312, 0.23296215, 0.19609227,
#        0.23318219, 0.15756019, 0.23517841, 0.21036081, 0.1587273 ,
#        0.21400002, 0.27434289, 0.16924808, 0.14388805, 0.17881355,
#        0.13480839, 0.21793765, 0.26978105])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Hesitant or Unsure\n")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Hesitant or Unsure
#
# R2 Score : 0.5746196545497282

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Strongly Hesitant

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    strg_hes_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1793, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.10483921, 0.07866085, 0.0997444 , 0.07019202, 0.06251902,
#        0.07344432, 0.0949849 , 0.06424531, 0.08125423, 0.0641979 ,
#        0.03924213, 0.07918346, 0.09820071, 0.07671889, 0.11570516,
#        0.08569315, 0.08536291, 0.05190007, 0.10016508, 0.07947666,
#        0.07510344, 0.04948406, 0.0730941 , 0.05809878, 0.06606627,
#        0.08967256, 0.08761935, 0.06488074, 0.084642  , 0.08097962,
#        0.07069632, 0.1109247 , 0.06000013, 0.08820782, 0.06130143,
#        0.11883434, 0.08576888, 0.05605666, 0.07393564, 0.07336534,
#        0.10444573, 0.1291541 , 0.10202392, 0.07829845, 0.08554262,
#        0.1086412 , 0.0548254 , 0.07410593, 0.08790839, 0.12233508,
#        0.10744638, 0.07119777, 0.0576266 , 0.07709449, 0.08178288,
#        0.11503362, 0.05687345, 0.12479037, 0.07257712, 0.0807751 ,
#        0.11634115, 0.06717452, 0.06459309, 0.07977506, 0.09186975,
#        0.11528901, 0.07166815, 0.10269005, 0.08725249, 0.05321178,
#        0.05971104, 0.13450855, 0.10557044, 0.07366987, 0.0739865 ,
#        0.08767195, 0.1004803 , 0.09429955, 0.08642063, 0.07178517,
#        0.0803118 , 0.09499244, 0.08983823, 0.08702475, 0.10224638,
#        0.08340096, 0.07278765, 0.07137701, 0.08233502, 0.10077758,
#        0.10813507, 0.07182595, 0.08607458, 0.11915465, 0.09094372,
#        0.06738574, 0.11996764, 0.07840109, 0.04923862, 0.13060206,
#        0.09646077, 0.07749607, 0.09046856, 0.07190525, 0.12960439,
#        0.13769078, 0.11492419, 0.09649142, 0.06056886, 0.0428893 ,
#        0.04407163, 0.12425649, 0.10230259, 0.10877911, 0.08329248,
#        0.08768505, 0.08982298, 0.10633838, 0.05951745, 0.11394553,
#        0.01562966, 0.05795735, 0.04902681, 0.1149533 , 0.10944988,
#        0.06371626, 0.11414445, 0.10960699, 0.10267619, 0.07990269,
#        0.12916749, 0.08885826, 0.07637759, 0.05331425, 0.07786493,
#        0.06309622, 0.09066234, 0.06532645, 0.10833829, 0.084649  ,
#        0.1061422 , 0.07372367, 0.11879855, 0.09076696, 0.07374249,
#        0.1075116 , 0.08204096, 0.05010011, 0.06728783, 0.12685807,
#        0.11209777, 0.09069966, 0.05635248, 0.08161362, 0.11843569,
#        0.06037452, 0.02694862, 0.06567005, 0.08935137, 0.11693785,
#        0.06133716, 0.11332894, 0.06437456, 0.0525143 , 0.06159782,
#        0.06962599, 0.10588719, 0.08598145, 0.09604   , 0.12913762,
#        0.04109776, 0.04022513, 0.00919825, 0.10535721, 0.01448294,
#        0.03707157, 0.10410426, 0.11043787, 0.11371442, 0.11512291,
#        0.0977638 , 0.0522674 , 0.08123646, 0.05717798, 0.10199142,
#        0.08606972, 0.07156959, 0.03896335, 0.10733769, 0.09206076,
#        0.08248717, 0.11829954, 0.08314221, 0.05364331, 0.0801718 ,
#        0.05095138, 0.07686549, 0.06842498, 0.07708683, 0.1133973 ,
#        0.09820552, 0.0949824 , 0.07554749, 0.08563455, 0.08069085,
#        0.06811101, 0.02454827, 0.02391412, 0.0799193 , 0.02620738,
#        0.0889015 , 0.05325183, 0.03155918, 0.06658147, 0.08323193,
#        0.09247843, 0.10633516, 0.05342467, 0.06368705, 0.09135193,
#        0.10748387, 0.08790387, 0.08871962, 0.07445219, 0.06408676,
#        0.06322094, 0.06434344, 0.10835223, 0.08264898, 0.08072424,
#        0.11083746, 0.12343939, 0.06613032, 0.0396385 , 0.08340845,
#        0.07422746, 0.04218162, 0.12258498, 0.06827206, 0.09706702,
#        0.08171352, 0.04010526, 0.07921841, 0.04875657, 0.08940367,
#        0.08447756, 0.07884766, 0.10228131, 0.06560767, 0.09309449,
#        0.10708555, 0.08300056, 0.08029451, 0.1085971 , 0.10424622,
#        0.09535976, 0.07935359, 0.12550046, 0.11527312, 0.09463774,
#        0.07084904, 0.09357587, 0.11105194, 0.0799    , 0.09861817,
#        0.07767536, 0.08789868, 0.03495757, 0.11098005, 0.06880306,
#        0.07844939, 0.06348166, 0.09892516, 0.07749266, 0.07486336,
#        0.10169259, 0.05239651, 0.06854259, 0.11617022, 0.08210426,
#        0.11951142, 0.0570156 , 0.08434129, 0.07491843, 0.03600799,
#        0.05561766, 0.05441082, 0.06804818, 0.08281175, 0.11909497,
#        0.07189339, 0.06302639, 0.04787875, 0.07273369, 0.08921984,
#        0.10988943, 0.08120314, 0.06664592, 0.07976768, 0.08105681,
#        0.06622728, 0.08188781, 0.08880803, 0.11878743, 0.10448783,
#        0.08107171, 0.10252108, 0.0612612 , 0.08379438, 0.07439217,
#        0.07611684, 0.0831619 , 0.10101599, 0.09832368, 0.11427841,
#        0.09566202, 0.08593807, 0.09371846, 0.08689661, 0.15008683,
#        0.05243564, 0.10431231, 0.06153026, 0.06740882, 0.10479235,
#        0.10616343, 0.10873007, 0.12686781, 0.0614088 , 0.09096774,
#        0.08526864, 0.10275903, 0.07417415, 0.06616065, 0.09762988,
#        0.092145  , 0.08794063, 0.08342218, 0.09150355, 0.08359265,
#        0.1240623 , 0.03474445, 0.08297835, 0.07645565, 0.06219923,
#        0.07261493, 0.06675235, 0.07386386, 0.04268356, 0.10261175,
#        0.09703652, 0.08613584, 0.0720003 , 0.08383417, 0.09220599,
#        0.05846485, 0.10029107, 0.10183733, 0.08797695, 0.05780243,
#        0.08963715, 0.08272066, 0.04794082, 0.09424183, 0.02660807,
#        0.11753689, 0.07270656, 0.1043182 , 0.08807459, 0.05958935,
#        0.06563811, 0.10322017, 0.05367748, 0.11344753, 0.09902406,
#        0.0875775 , 0.11252945, 0.07246838, 0.12025574, 0.10501476,
#        0.11094766, 0.06872161, 0.08990526, 0.11189788, 0.06627163,
#        0.11191602, 0.14059058, 0.08235972, 0.05506103, 0.08402838,
#        0.04907784, 0.09581271, 0.12011874])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Strongly Hesitant")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Strongly Hesitant
# R2 Score : 0.5428491364996555
