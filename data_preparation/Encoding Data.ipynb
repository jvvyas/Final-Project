# %% [markdown]
# # Encoding the COVID Dataset
#
# This file contains datasets to be used in the final project. The preprocessing demonstrated at the end of this notebook show how we would begin encoding the data to prepare it for machine learning.

# %%
# Add the Pandas dependency.
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Files to load
covid_data_to_load = "Resources/Covid19vaccinesbycounty.csv"
mask_data_to_load = "Resources/US_State_and_Territorial_Public_Mask_Mandates_by_County_by_Day.csv"
vaccine_data_to_load = "Resources/Vaccine_Hesitancy_for_COVID_County_and_local_estimates.csv"

# %%
# Add the dependencies.
import pandas as pd
import os

# %%
# Files to load
covid_data_to_load = os.path.join("Resources", "Covid19vaccinesbycounty.csv")
mask_data_to_load = os.path.join("Resources", "US_State_and_Territorial_Public_Mask_Mandates_by_County_by_Day.csv")
vaccine_data_to_load = os.path.join("Resources", "Vaccine_Hesitancy_for_COVID_County_and_local_estimates.csv")

# %%
# Read the covid data file and store it in a Pandas DataFrame.
# covid_data_df = pd.read_csv(covid_data_to_load)
# covid_data_df

# %%
# Rename column
# covid_data_df.rename(columns = {'county':'County_Name'}, inplace = True)
# covid_data_df

# %%
# Read the mask data file and store it in a Pandas DataFrame.
mask_data_df = pd.read_csv(mask_data_to_load)
mask_data_df
# Out:
#         State_Tribe_Territory        County_Name  FIPS_Code        Date  \
# 0                       Texas              Nolan      48353  2020-03-11
# 1                     Georgia              Baker      13007  2020-03-17
# 2                     Indiana             Fulton      18049  2022-02-14
# 3                        Iowa             Greene      19073  2020-07-28
# 4                      Kansas         Montgomery      20125  2020-03-13
# ...                       ...                ...        ...         ...
# 2562115   U.S. Virgin Islands    St. John Island      78020  2020-07-16
# 2562116   U.S. Virgin Islands    St. John Island      78020  2022-01-02
# 2562117   U.S. Virgin Islands    St. John Island      78020  2022-03-04
# 2562118   U.S. Virgin Islands    St. John Island      78020  2022-04-01
# 2562119   U.S. Virgin Islands  St. Thomas Island      78030  2021-07-10
#
#          Masks_Order_Code Face_Masks_Required_in_Public  \
# 0                       2                           NaN
# 1                       2                           NaN
# 2                       2                           NaN
# 3                       2                           NaN
# 4                       2                           NaN
# ...                   ...                           ...
# 2562115                 1           Public mask mandate
# 2562116                 1           Public mask mandate
# 2562117                 1           Public mask mandate
# 2562118                 2        No public mask mandate
# 2562119                 1           Public mask mandate
#
#                                                  Citations
# 0                                                      NaN
# 1                                                      NaN
# 2                           [Ind. HB 1405 (Apr. 29, 2021)]
# 3                             [Iowa Proc. (Jul. 24, 2020)]
# 4                                                      NaN
# ...                                                    ...
# 2562115  [USVI. Exec. Order (Jul. 1, 2020), V.I. Supple...
# 2562116  [V.I. Thirtieth Supp. Exec. Order (Oct. 4, 202...
# 2562117  [V.I. Sixteenth Supp. Exec. Order (Sept. 8, 20...
# 2562118  [V.I. Press Release (Mar. 14, 2022) (lifts ind...
# 2562119  [V.I. Twenty-Fourth Supp. Exec. Order (May 25,...
#
# [2562120 rows x 7 columns]

# %%
# Read the vaccine data file and store it in a Pandas DataFrame.
vaccine_data_df = pd.read_csv(vaccine_data_to_load)
vaccine_data_df
# Out:
#       FIPS Code                    County Name      State  Estimated hesitant  \
# 0          1123     Tallapoosa County, Alabama    ALABAMA              0.1806
# 1          1121      Talladega County, Alabama    ALABAMA              0.1783
# 2          1131         Wilcox County, Alabama    ALABAMA              0.1735
# 3          1129     Washington County, Alabama    ALABAMA              0.1735
# 4          1133        Winston County, Alabama    ALABAMA              0.1805
# ...         ...                            ...        ...                 ...
# 3137      55079    Milwaukee County, Wisconsin  WISCONSIN              0.1505
# 3138      55121  Trempealeau County, Wisconsin  WISCONSIN              0.1611
# 3139      56001         Albany County, Wyoming    WYOMING              0.1949
# 3140      55067     Langlade County, Wisconsin  WISCONSIN              0.1518
# 3141      55099        Price County, Wisconsin  WISCONSIN              0.1528
#
#       Estimated hesitant or unsure  Estimated strongly hesitant  \
# 0                           0.2400                       0.1383
# 1                           0.2350                       0.1368
# 2                           0.2357                       0.1337
# 3                           0.2357                       0.1337
# 4                           0.2313                       0.1379
# ...                            ...                          ...
# 3137                        0.2144                       0.0880
# 3138                        0.2126                       0.0959
# 3139                        0.2673                       0.1405
# 3140                        0.2007                       0.0906
# 3141                        0.2039                       0.0906
#
#       Social Vulnerability Index (SVI)             SVI Category  \
# 0                                 0.89  Very High Vulnerability
# 1                                 0.87  Very High Vulnerability
# 2                                 0.93  Very High Vulnerability
# 3                                 0.73       High Vulnerability
# 4                                 0.70       High Vulnerability
# ...                                ...                      ...
# 3137                              0.81  Very High Vulnerability
# 3138                              0.28        Low Vulnerability
# 3139                              0.25        Low Vulnerability
# 3140                              0.35        Low Vulnerability
# 3141                              0.16   Very Low Vulnerability
#
#       CVAC level of concern for vaccination rollout CVAC Level Of Concern  \
# 0                                              0.64          High Concern
# 1                                              0.84     Very High Concern
# 2                                              0.94     Very High Concern
# 3                                              0.82     Very High Concern
# 4                                              0.80          High Concern
# ...                                             ...                   ...
# 3137                                           0.30           Low Concern
# 3138                                           0.31           Low Concern
# 3139                                           0.63          High Concern
# 3140                                           0.19      Very Low Concern
# 3141                                           0.20      Very Low Concern
#
#       ...  Percent Hispanic  \
# 0     ...            0.0242
# 1     ...            0.0229
# 2     ...            0.0053
# 3     ...            0.0146
# 4     ...            0.0315
# ...   ...               ...
# 3137  ...            0.1500
# 3138  ...            0.0840
# 3139  ...            0.0953
# 3140  ...            0.0197
# 3141  ...            0.0177
#
#       Percent non-Hispanic American Indian/Alaska Native  \
# 0                                                0.0022
# 1                                                0.0043
# 2                                                0.0009
# 3                                                0.0731
# 4                                                0.0034
# ...                                                 ...
# 3137                                             0.0047
# 3138                                             0.0034
# 3139                                             0.0091
# 3140                                             0.0069
# 3141                                             0.0096
#
#       Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# 0                         0.0036                      0.2697
# 1                         0.0061                      0.3237
# 2                         0.0003                      0.6938
# 3                         0.0025                      0.2354
# 4                         0.0016                      0.0073
# ...                          ...                         ...
# 3137                      0.0428                      0.2606
# 3138                      0.0043                      0.0051
# 3139                      0.0327                      0.0150
# 3140                      0.0022                      0.0125
# 3141                      0.0060                      0.0083
#
#       Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# 0                                                0.0000
# 1                                                0.0003
# 2                                                0.0000
# 3                                                0.0000
# 4                                                0.0005
# ...                                                 ...
# 3137                                             0.0002
# 3138                                             0.0000
# 3139                                             0.0003
# 3140                                             0.0002
# 3141                                             0.0085
#
#       Percent non-Hispanic White            Geographical Point State Code  \
# 0                         0.6887  POINT (-86.844516 32.756889)         AL
# 1                         0.6263  POINT (-86.844516 32.756889)         AL
# 2                         0.2684  POINT (-86.844516 32.756889)         AL
# 3                         0.6495  POINT (-86.844516 32.756889)         AL
# 4                         0.9370  POINT (-86.844516 32.756889)         AL
# ...                          ...                           ...        ...
# 3137                      0.5124  POINT (-89.732969 44.639954)         WI
# 3138                      0.8953  POINT (-89.732969 44.639954)         WI
# 3139                      0.8248  POINT (-107.55145 42.999627)         WY
# 3140                      0.9383  POINT (-89.732969 44.639954)         WI
# 3141                      0.9407  POINT (-89.732969 44.639954)         WI
#
#                                         County Boundary  \
# 0     MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1     MULTIPOLYGON (((-86.303069 33.46316, -86.30306...
# 2     MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 3     MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 4     MULTIPOLYGON (((-87.63656399999999 34.120908, ...
# ...                                                 ...
# 3137  MULTIPOLYGON (((-87.994171 43.19255, -87.99331...
# 3138  MULTIPOLYGON (((-91.529034 44.422101, -91.5292...
# 3139  MULTIPOLYGON (((-106.071399 41.530719999999995...
# 3140  MULTIPOLYGON (((-89.42472 45.293175, -89.42473...
# 3141  MULTIPOLYGON (((-90.677753 45.725133, -90.6777...
#
#                                          State Boundary
# 0     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 1     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 2     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 3     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 4     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# ...                                                 ...
# 3137  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3138  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3139  MULTIPOLYGON (((-111.044893 43.315719, -111.04...
# 3140  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3141  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
#
# [3142 rows x 21 columns]

# %%
# Rename column
vaccine_data_df.rename(columns = {'FIPS Code':'FIPS_Code'}, inplace = True)
vaccine_data_df
# Out:
#       FIPS_Code                    County Name      State  Estimated hesitant  \
# 0          1123     Tallapoosa County, Alabama    ALABAMA              0.1806
# 1          1121      Talladega County, Alabama    ALABAMA              0.1783
# 2          1131         Wilcox County, Alabama    ALABAMA              0.1735
# 3          1129     Washington County, Alabama    ALABAMA              0.1735
# 4          1133        Winston County, Alabama    ALABAMA              0.1805
# ...         ...                            ...        ...                 ...
# 3137      55079    Milwaukee County, Wisconsin  WISCONSIN              0.1505
# 3138      55121  Trempealeau County, Wisconsin  WISCONSIN              0.1611
# 3139      56001         Albany County, Wyoming    WYOMING              0.1949
# 3140      55067     Langlade County, Wisconsin  WISCONSIN              0.1518
# 3141      55099        Price County, Wisconsin  WISCONSIN              0.1528
#
#       Estimated hesitant or unsure  Estimated strongly hesitant  \
# 0                           0.2400                       0.1383
# 1                           0.2350                       0.1368
# 2                           0.2357                       0.1337
# 3                           0.2357                       0.1337
# 4                           0.2313                       0.1379
# ...                            ...                          ...
# 3137                        0.2144                       0.0880
# 3138                        0.2126                       0.0959
# 3139                        0.2673                       0.1405
# 3140                        0.2007                       0.0906
# 3141                        0.2039                       0.0906
#
#       Social Vulnerability Index (SVI)             SVI Category  \
# 0                                 0.89  Very High Vulnerability
# 1                                 0.87  Very High Vulnerability
# 2                                 0.93  Very High Vulnerability
# 3                                 0.73       High Vulnerability
# 4                                 0.70       High Vulnerability
# ...                                ...                      ...
# 3137                              0.81  Very High Vulnerability
# 3138                              0.28        Low Vulnerability
# 3139                              0.25        Low Vulnerability
# 3140                              0.35        Low Vulnerability
# 3141                              0.16   Very Low Vulnerability
#
#       CVAC level of concern for vaccination rollout CVAC Level Of Concern  \
# 0                                              0.64          High Concern
# 1                                              0.84     Very High Concern
# 2                                              0.94     Very High Concern
# 3                                              0.82     Very High Concern
# 4                                              0.80          High Concern
# ...                                             ...                   ...
# 3137                                           0.30           Low Concern
# 3138                                           0.31           Low Concern
# 3139                                           0.63          High Concern
# 3140                                           0.19      Very Low Concern
# 3141                                           0.20      Very Low Concern
#
#       ...  Percent Hispanic  \
# 0     ...            0.0242
# 1     ...            0.0229
# 2     ...            0.0053
# 3     ...            0.0146
# 4     ...            0.0315
# ...   ...               ...
# 3137  ...            0.1500
# 3138  ...            0.0840
# 3139  ...            0.0953
# 3140  ...            0.0197
# 3141  ...            0.0177
#
#       Percent non-Hispanic American Indian/Alaska Native  \
# 0                                                0.0022
# 1                                                0.0043
# 2                                                0.0009
# 3                                                0.0731
# 4                                                0.0034
# ...                                                 ...
# 3137                                             0.0047
# 3138                                             0.0034
# 3139                                             0.0091
# 3140                                             0.0069
# 3141                                             0.0096
#
#       Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# 0                         0.0036                      0.2697
# 1                         0.0061                      0.3237
# 2                         0.0003                      0.6938
# 3                         0.0025                      0.2354
# 4                         0.0016                      0.0073
# ...                          ...                         ...
# 3137                      0.0428                      0.2606
# 3138                      0.0043                      0.0051
# 3139                      0.0327                      0.0150
# 3140                      0.0022                      0.0125
# 3141                      0.0060                      0.0083
#
#       Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# 0                                                0.0000
# 1                                                0.0003
# 2                                                0.0000
# 3                                                0.0000
# 4                                                0.0005
# ...                                                 ...
# 3137                                             0.0002
# 3138                                             0.0000
# 3139                                             0.0003
# 3140                                             0.0002
# 3141                                             0.0085
#
#       Percent non-Hispanic White            Geographical Point State Code  \
# 0                         0.6887  POINT (-86.844516 32.756889)         AL
# 1                         0.6263  POINT (-86.844516 32.756889)         AL
# 2                         0.2684  POINT (-86.844516 32.756889)         AL
# 3                         0.6495  POINT (-86.844516 32.756889)         AL
# 4                         0.9370  POINT (-86.844516 32.756889)         AL
# ...                          ...                           ...        ...
# 3137                      0.5124  POINT (-89.732969 44.639954)         WI
# 3138                      0.8953  POINT (-89.732969 44.639954)         WI
# 3139                      0.8248  POINT (-107.55145 42.999627)         WY
# 3140                      0.9383  POINT (-89.732969 44.639954)         WI
# 3141                      0.9407  POINT (-89.732969 44.639954)         WI
#
#                                         County Boundary  \
# 0     MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1     MULTIPOLYGON (((-86.303069 33.46316, -86.30306...
# 2     MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 3     MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 4     MULTIPOLYGON (((-87.63656399999999 34.120908, ...
# ...                                                 ...
# 3137  MULTIPOLYGON (((-87.994171 43.19255, -87.99331...
# 3138  MULTIPOLYGON (((-91.529034 44.422101, -91.5292...
# 3139  MULTIPOLYGON (((-106.071399 41.530719999999995...
# 3140  MULTIPOLYGON (((-89.42472 45.293175, -89.42473...
# 3141  MULTIPOLYGON (((-90.677753 45.725133, -90.6777...
#
#                                          State Boundary
# 0     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 1     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 2     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 3     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 4     MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# ...                                                 ...
# 3137  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3138  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3139  MULTIPOLYGON (((-111.044893 43.315719, -111.04...
# 3140  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
# 3141  MULTIPOLYGON (((-92.887067 45.644148, -92.8825...
#
# [3142 rows x 21 columns]

# %%
# Combine the mask dataframe and vaccine dataframe into a single dataset.
covid_complete_df = pd.merge(vaccine_data_df, mask_data_df, on=["FIPS_Code"])
covid_complete_df.head()
# Out:
#    FIPS_Code                 County Name    State  Estimated hesitant  \
# 0       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 1       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 2       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 3       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 4       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
#
#    Estimated hesitant or unsure  Estimated strongly hesitant  \
# 0                          0.24                       0.1383
# 1                          0.24                       0.1383
# 2                          0.24                       0.1383
# 3                          0.24                       0.1383
# 4                          0.24                       0.1383
#
#    Social Vulnerability Index (SVI)             SVI Category  \
# 0                              0.89  Very High Vulnerability
# 1                              0.89  Very High Vulnerability
# 2                              0.89  Very High Vulnerability
# 3                              0.89  Very High Vulnerability
# 4                              0.89  Very High Vulnerability
#
#    CVAC level of concern for vaccination rollout CVAC Level Of Concern  ...  \
# 0                                           0.64          High Concern  ...
# 1                                           0.64          High Concern  ...
# 2                                           0.64          High Concern  ...
# 3                                           0.64          High Concern  ...
# 4                                           0.64          High Concern  ...
#
#              Geographical Point  State Code  \
# 0  POINT (-86.844516 32.756889)          AL
# 1  POINT (-86.844516 32.756889)          AL
# 2  POINT (-86.844516 32.756889)          AL
# 3  POINT (-86.844516 32.756889)          AL
# 4  POINT (-86.844516 32.756889)          AL
#
#                                      County Boundary  \
# 0  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 2  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 3  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 4  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
#
#                                       State Boundary  State_Tribe_Territory  \
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 4  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
#
#    County_Name        Date Masks_Order_Code Face_Masks_Required_in_Public  \
# 0   Tallapoosa  2020-03-15                2                           NaN
# 1   Tallapoosa  2020-05-03                2                           NaN
# 2   Tallapoosa  2020-11-03                1           Public mask mandate
# 3   Tallapoosa  2021-10-27                2                           NaN
# 4   Tallapoosa  2022-03-06                2                           NaN
#
#                                            Citations
# 0                                                NaN
# 1  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 2  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 3    [Ala. Health Order (Safer Apart) (May 3, 2021)]
# 4    [Ala. Health Order (Safer Apart) (May 3, 2021)]
#
# [5 rows x 27 columns]

# %%
# Encoding SVI Category
le = LabelEncoder()
SVI_category_encoded = covid_complete_df
SVI_category_encoded['SVI Category'] = le.fit_transform(SVI_category_encoded['SVI Category'])
SVI_category_encoded.head()
# Out:
#    FIPS_Code                 County Name    State  Estimated hesitant  \
# 0       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 1       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 2       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 3       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 4       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
#
#    Estimated hesitant or unsure  Estimated strongly hesitant  \
# 0                          0.24                       0.1383
# 1                          0.24                       0.1383
# 2                          0.24                       0.1383
# 3                          0.24                       0.1383
# 4                          0.24                       0.1383
#
#    Social Vulnerability Index (SVI)  SVI Category  \
# 0                              0.89             3
# 1                              0.89             3
# 2                              0.89             3
# 3                              0.89             3
# 4                              0.89             3
#
#    CVAC level of concern for vaccination rollout CVAC Level Of Concern  ...  \
# 0                                           0.64          High Concern  ...
# 1                                           0.64          High Concern  ...
# 2                                           0.64          High Concern  ...
# 3                                           0.64          High Concern  ...
# 4                                           0.64          High Concern  ...
#
#              Geographical Point  State Code  \
# 0  POINT (-86.844516 32.756889)          AL
# 1  POINT (-86.844516 32.756889)          AL
# 2  POINT (-86.844516 32.756889)          AL
# 3  POINT (-86.844516 32.756889)          AL
# 4  POINT (-86.844516 32.756889)          AL
#
#                                      County Boundary  \
# 0  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 2  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 3  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 4  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
#
#                                       State Boundary  State_Tribe_Territory  \
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 4  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
#
#    County_Name        Date Masks_Order_Code Face_Masks_Required_in_Public  \
# 0   Tallapoosa  2020-03-15                2                           NaN
# 1   Tallapoosa  2020-05-03                2                           NaN
# 2   Tallapoosa  2020-11-03                1           Public mask mandate
# 3   Tallapoosa  2021-10-27                2                           NaN
# 4   Tallapoosa  2022-03-06                2                           NaN
#
#                                            Citations
# 0                                                NaN
# 1  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 2  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 3    [Ala. Health Order (Safer Apart) (May 3, 2021)]
# 4    [Ala. Health Order (Safer Apart) (May 3, 2021)]
#
# [5 rows x 27 columns]

# %%
# Encoding CVAC Level of Concern
le = LabelEncoder()
CVAC_encoded = SVI_category_encoded
CVAC_encoded['CVAC Level Of Concern'] = le.fit_transform(CVAC_encoded['CVAC Level Of Concern'])
CVAC_encoded.head()
# Out:
#    FIPS_Code                 County Name    State  Estimated hesitant  \
# 0       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 1       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 2       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 3       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 4       1123  Tallapoosa County, Alabama  ALABAMA              0.1806
#
#    Estimated hesitant or unsure  Estimated strongly hesitant  \
# 0                          0.24                       0.1383
# 1                          0.24                       0.1383
# 2                          0.24                       0.1383
# 3                          0.24                       0.1383
# 4                          0.24                       0.1383
#
#    Social Vulnerability Index (SVI)  SVI Category  \
# 0                              0.89             3
# 1                              0.89             3
# 2                              0.89             3
# 3                              0.89             3
# 4                              0.89             3
#
#    CVAC level of concern for vaccination rollout  CVAC Level Of Concern  ...  \
# 0                                           0.64                      0  ...
# 1                                           0.64                      0  ...
# 2                                           0.64                      0  ...
# 3                                           0.64                      0  ...
# 4                                           0.64                      0  ...
#
#              Geographical Point  State Code  \
# 0  POINT (-86.844516 32.756889)          AL
# 1  POINT (-86.844516 32.756889)          AL
# 2  POINT (-86.844516 32.756889)          AL
# 3  POINT (-86.844516 32.756889)          AL
# 4  POINT (-86.844516 32.756889)          AL
#
#                                      County Boundary  \
# 0  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 2  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 3  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 4  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
#
#                                       State Boundary  State_Tribe_Territory  \
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
# 4  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                Alabama
#
#    County_Name        Date Masks_Order_Code Face_Masks_Required_in_Public  \
# 0   Tallapoosa  2020-03-15                2                           NaN
# 1   Tallapoosa  2020-05-03                2                           NaN
# 2   Tallapoosa  2020-11-03                1           Public mask mandate
# 3   Tallapoosa  2021-10-27                2                           NaN
# 4   Tallapoosa  2022-03-06                2                           NaN
#
#                                            Citations
# 0                                                NaN
# 1  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 2  [Ala. Health Order (Nov. 5, 2020), Ala. Health...
# 3    [Ala. Health Order (Safer Apart) (May 3, 2021)]
# 4    [Ala. Health Order (Safer Apart) (May 3, 2021)]
#
# [5 rows x 27 columns]
