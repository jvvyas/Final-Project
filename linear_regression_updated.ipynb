# %% [markdown]
# # Linear Regression Models
#
# Our team created three linear regression models to predict U.S. counties' estimated hesitant, hesitant or unsure, and strongly hesistant rates, respectively, based on 25 features.
#
# -----------------------------
# ### **Feature Groups**
#
# **Vaccine Availability:**
# 1. `the_number_of_providers` per FIPS code
# 2. `the_average_supply_level` for all location providers per FIPS code
#
# **Community Risk/Vaccination Measures:**
#
# 3. `social_vulnerability_index_svi` ranges from 0 (least) to 1 (most) to measure community's vulnerability to disaster
# 4. `cvac_level_of_concern_for_vaccination_rollout` ranges from 0 (lowest) to 1 (highest) for concern for difficult vaccine rollout
# 5. `percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21`
# 6. `community_transmission_level` is either low, moderate, substantial, or high rate of transmission:
# * based on total new COVID-19 cases per 100,000 persons in the last 7 days and percentage of positive SARS-CoV-2 diagnostic nucleic acid amplification tests (NAAT) in the last 7 days (higher of the two if different)
# 7. `completeness_pct` tells percent of people fully vaccinated with a reported, valid county FIPS code in the jurisdiction
#
# **Orders/Bans and Other Guidance:**
#
# 8. `masks_order_code`where 1 = public mask mandate; 2 = no public mask mandate
# 9. `general_gb_order_code` indicates size of gatherings banned:
# * 1 = No order (for gathering ban) found
# * 6 = Ban of gatherings over 1-10 people
# * 4 = Ban of gatherings over 26-50 people
# * 2 = Ban of gatherings over 101 or more people
# * 7 = Bans gatherings of any size
# 10. `general_or_under_6ft_bans_gatherings_over` tells max number of people that can gather without social distancing:
# * No ban, 0, 6, 8, 10, 50, 150, or 250
# 11. `stay_at_home_order_code` based on stay at home order recommendation:
# * 7 = No order for individuals to stay home or NA
# * 6 = Advisory/Recommendation
# * 3 = Mandatory only for at-risk individuals in the jurisdiction
#
# **Health Conditions** (county average estimates of prevalence of specified health conditions in adults 2019):
#
# 12. `avg_asthma`
# 13. `avg_chd` (coronary heart disease)
# 14. `avg_checkup`
# 15. `avg_copd` (chronic obstructive pulmonary disease)
# 16. `avg_smoking`
# 17. `avg_depression`
# 18. `avg_diabetes`
# 19. `avg_ghlth` for fair or poor health
# 20. `avg_lpa` for no leisure-time physical activity
# 21. `avg_mhlth` for mental health not good for >=14 days
# 22. `avg_obesity`
# 23. `avg_sleep` for sleeping less than 7 hours
#
# **Other:**
#
# 24. `fips_code` is Federal Information Processing Standards (FIPS) Code; unique to each county
# 25. `metro_status` for metro (metropolitan county) vs non-metro

# %% [markdown]
# # Clean Data:

# %%
# import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# load file
df = pd.read_csv(Path('Resources/(new)joined_8_tables_on_county_level.csv'))
df
# Out:
#       county_fips_code  the_number_of_providers  the_average_supply_level  \
# 0                10001                      195                  0.333333
# 1                10003                      638                  0.194357
# 2                10005                      295                  0.196610
# 3                11001                      678                  0.244838
# 4                12001                      345                  0.382609
# ...                ...                      ...                       ...
# 2616             56037                       39                  0.102564
# 2617             56039                       15                  0.000000
# 2618             56041                       33                 -0.090909
# 2619             56043                        7                 -0.714286
# 2620             56045                       12                 -0.500000
#
#       fips_code                                 county_name  \
# 0         10001                       Kent County, Delaware
# 1         10003                 New Castle County, Delaware
# 2         10005                     Sussex County, Delaware
# 3         11001  District of Columbia, District of Columbia
# 4         12001                     Alachua County, Florida
# ...         ...                                         ...
# 2616      56037                  Sweetwater County, Wyoming
# 2617      56039                       Teton County, Wyoming
# 2618      56041                       Uinta County, Wyoming
# 2619      56043                    Washakie County, Wyoming
# 2620      56045                      Weston County, Wyoming
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  ...  avg_checkup  \
# 0                 0.0664                        0.1391  ...    80.593750
# 1                 0.0564                        0.1180  ...    79.198450
# 2                 0.0555                        0.1121  ...    81.164151
# 3                 0.0655                        0.0850  ...    79.094944
# 4                 0.1167                        0.1711  ...    76.055357
# ...                  ...                           ...  ...          ...
# 2616              0.2184                        0.2843  ...    65.275000
# 2617              0.2050                        0.2671  ...    65.425000
# 2618              0.2184                        0.2843  ...    63.466667
# 2619              0.2283                        0.2943  ...    66.966667
# 2620              0.2283                        0.2943  ...    67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 37 columns]

# %%
df.dtypes
# Out:
# county_fips_code                                                    int64
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# county_name                                                        object
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# completeness_pct                                                  float64
# metro_status                                                       object
# series_complete_pop_pct                                           float64
# series_complete_yes                                               float64
# series_complete_pop_pct_svi                                       float64
# series_complete_pop_pct_ur_equity                                 float64
# general_gb_order_code                                               int64
# general_gb_order_group                                             object
# general_or_under_6ft_bans_gatherings_over                          object
# indoor_outdoor                                                    float64
# stay_at_home_order_code                                             int64
# community_transmission_level                                       object
# cases_per_100k_7_day_count_change                                  object
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %%
# drop redundant columns
df = df.drop(['county_fips_code', 'county_name', 'indoor_outdoor', 'series_complete_pop_pct', 'series_complete_yes', 'series_complete_pop_pct_svi', 'series_complete_pop_pct_ur_equity', 'general_gb_order_group', 'cases_per_100k_7_day_count_change'], axis=1)
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ...  avg_checkup  \
# 0                          0.0388                 2  ...    80.593750
# 1                          0.0329                 2  ...    79.198450
# 2                          0.0328                 2  ...    81.164151
# 3                          0.0403                 2  ...    79.094944
# 4                          0.0755                 2  ...    76.055357
# ...                           ...               ...  ...          ...
# 2616                       0.1584                 2  ...    65.275000
# 2617                       0.1472                 2  ...    65.425000
# 2618                       0.1584                 2  ...    63.466667
# 2619                       0.1687                 2  ...    66.966667
# 2620                       0.1687                 2  ...    67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 28 columns]

# %%
## check total nulls per column
df.isnull().sum()
# Out:
# the_number_of_providers                                             0
# the_average_supply_level                                            0
# fips_code                                                           0
# social_vulnerability_index_svi                                      1
# cvac_level_of_concern_for_vaccination_rollout                       0
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    214
# estimated_hesitant                                                  0
# estimated_hesitant_or_unsure                                        0
# estimated_strongly_hesitant                                         0
# masks_order_code                                                    0
# completeness_pct                                                    0
# metro_status                                                        0
# general_gb_order_code                                               0
# general_or_under_6ft_bans_gatherings_over                         201
# stay_at_home_order_code                                             0
# community_transmission_level                                        0
# avg_asthma                                                         21
# avg_chd                                                            21
# avg_checkup                                                        21
# avg_copd                                                           21
# avg_smoking                                                        21
# avg_depression                                                     21
# avg_diabetes                                                       21
# avg_ghlth                                                          21
# avg_lpa                                                            21
# avg_mhlth                                                          21
# avg_obesity                                                        21
# avg_sleep                                                           0
# dtype: int64

# %%
# fill nulls: since 'percent_adults_fully_vaccinated' is continous data, fill with mean values (Mean Completer)
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(missing_values = np.NaN, strategy='mean',add_indicator=True)
mode_imputer = SimpleImputer(missing_values = np.NaN, strategy='most_frequent', add_indicator=True)

vaccine_series = mean_imputer.fit_transform(np.array(df['percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21']).reshape(-1,1))

df['percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21'] = np.array(vaccine_series)
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ...  avg_checkup  \
# 0                          0.0388                 2  ...    80.593750
# 1                          0.0329                 2  ...    79.198450
# 2                          0.0328                 2  ...    81.164151
# 3                          0.0403                 2  ...    79.094944
# 4                          0.0755                 2  ...    76.055357
# ...                           ...               ...  ...          ...
# 2616                       0.1584                 2  ...    65.275000
# 2617                       0.1472                 2  ...    65.425000
# 2618                       0.1584                 2  ...    63.466667
# 2619                       0.1687                 2  ...    66.966667
# 2620                       0.1687                 2  ...    67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2621 rows x 28 columns]

# %%
## check total nulls per column
df.isnull().sum()
# Out:
# the_number_of_providers                                             0
# the_average_supply_level                                            0
# fips_code                                                           0
# social_vulnerability_index_svi                                      1
# cvac_level_of_concern_for_vaccination_rollout                       0
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21      0
# estimated_hesitant                                                  0
# estimated_hesitant_or_unsure                                        0
# estimated_strongly_hesitant                                         0
# masks_order_code                                                    0
# completeness_pct                                                    0
# metro_status                                                        0
# general_gb_order_code                                               0
# general_or_under_6ft_bans_gatherings_over                         201
# stay_at_home_order_code                                             0
# community_transmission_level                                        0
# avg_asthma                                                         21
# avg_chd                                                            21
# avg_checkup                                                        21
# avg_copd                                                           21
# avg_smoking                                                        21
# avg_depression                                                     21
# avg_diabetes                                                       21
# avg_ghlth                                                          21
# avg_lpa                                                            21
# avg_mhlth                                                          21
# avg_obesity                                                        21
# avg_sleep                                                           0
# dtype: int64

# %%
# drop nulls
df = df.dropna()
df
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ...  avg_checkup  \
# 0                          0.0388                 2  ...    80.593750
# 1                          0.0329                 2  ...    79.198450
# 2                          0.0328                 2  ...    81.164151
# 3                          0.0403                 2  ...    79.094944
# 4                          0.0755                 2  ...    76.055357
# ...                           ...               ...  ...          ...
# 2616                       0.1584                 2  ...    65.275000
# 2617                       0.1472                 2  ...    65.425000
# 2618                       0.1584                 2  ...    63.466667
# 2619                       0.1687                 2  ...    66.966667
# 2620                       0.1687                 2  ...    67.300000
#
#       avg_copd  avg_smoking avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875      20.575000     12.378125  20.303125
# 1     7.067442    16.818605      20.256589     10.819380  18.208527
# 2     9.215094    16.686792      18.324528     12.662264  19.600000
# 3     4.977528    15.800000      20.562921      9.938202  16.479775
# 4     7.030357    16.417857      21.016071      9.007143  17.764286
# ...        ...          ...            ...           ...        ...
# 2616  5.983333    18.658333      19.225000      7.541667  15.700000
# 2617  4.425000    12.175000      16.825000      6.025000  10.950000
# 2618  7.200000    20.266667      19.833333      8.066667  17.100000
# 2619  8.033333    18.133333      18.000000     10.433333  18.466667
# 2620  8.000000    19.250000      18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2398 rows x 28 columns]

# %% [markdown]
# ##### 223 rows with nulls were dropped; we do not believe this will have a huge impact on our data given the abundance of data remaining

# %% [markdown]
# # Pre-process/Encode Data:

# %%
# view data types
df.dtypes
# Out:
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# completeness_pct                                                  float64
# metro_status                                                       object
# general_gb_order_code                                               int64
# general_or_under_6ft_bans_gatherings_over                          object
# stay_at_home_order_code                                             int64
# community_transmission_level                                       object
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %%
# show columns with object data types and their unique values count
df_cols_to_encode = df.dtypes[df.dtypes == 'object'].index
df[df_cols_to_encode].nunique()
# Out:
# metro_status                                 2
# general_or_under_6ft_bans_gatherings_over    8
# community_transmission_level                 4
# dtype: int64

# %%
# print unique values in object columns
for i in df_cols_to_encode:
    print(f"{i}: {df[i].unique()}\n")
# Out:
# metro_status: ['Metro' 'Non-metro']
#
# general_or_under_6ft_bans_gatherings_over: ['No ban' '10' '50' '150' '250' '6' '8' '0']
#
# community_transmission_level: ['moderate' 'low' 'substantial' 'high']

# %%
# label encoder for object type columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_new = df.copy()
df_new['metro_status'] = le.fit_transform(df_new['metro_status'])
df_new['general_or_under_6ft_bans_gatherings_over'] = le.fit_transform(df_new['general_or_under_6ft_bans_gatherings_over'])
df_new['community_transmission_level'] = le.fit_transform(df_new['community_transmission_level'])
df_new
# Out:
#       the_number_of_providers  the_average_supply_level  fips_code  \
# 0                         195                  0.333333      10001
# 1                         638                  0.194357      10003
# 2                         295                  0.196610      10005
# 3                         678                  0.244838      11001
# 4                         345                  0.382609      12001
# ...                       ...                       ...        ...
# 2616                       39                  0.102564      56037
# 2617                       15                  0.000000      56039
# 2618                       33                 -0.090909      56041
# 2619                        7                 -0.714286      56043
# 2620                       12                 -0.500000      56045
#
#       social_vulnerability_index_svi  \
# 0                               0.73
# 1                               0.38
# 2                               0.40
# 3                               0.60
# 4                               0.47
# ...                              ...
# 2616                            0.37
# 2617                            0.11
# 2618                            0.45
# 2619                            0.37
# 2620                            0.35
#
#       cvac_level_of_concern_for_vaccination_rollout  \
# 0                                              0.32
# 1                                              0.16
# 2                                              0.12
# 3                                              0.17
# 4                                              0.63
# ...                                             ...
# 2616                                           0.56
# 2617                                           0.44
# 2618                                           0.48
# 2619                                           0.69
# 2620                                           0.51
#
#       percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                                 0.435
# 1                                                 0.552
# 2                                                 0.569
# 3                                                 0.546
# 4                                                 0.547
# ...                                                 ...
# 2616                                              0.348
# 2617                                              0.789
# 2618                                              0.388
# 2619                                              0.364
# 2620                                              0.311
#
#       estimated_hesitant  estimated_hesitant_or_unsure  \
# 0                 0.0664                        0.1391
# 1                 0.0564                        0.1180
# 2                 0.0555                        0.1121
# 3                 0.0655                        0.0850
# 4                 0.1167                        0.1711
# ...                  ...                           ...
# 2616              0.2184                        0.2843
# 2617              0.2050                        0.2671
# 2618              0.2184                        0.2843
# 2619              0.2283                        0.2943
# 2620              0.2283                        0.2943
#
#       estimated_strongly_hesitant  masks_order_code  ...  avg_checkup  \
# 0                          0.0388                 2  ...    80.593750
# 1                          0.0329                 2  ...    79.198450
# 2                          0.0328                 2  ...    81.164151
# 3                          0.0403                 2  ...    79.094944
# 4                          0.0755                 2  ...    76.055357
# ...                           ...               ...  ...          ...
# 2616                       0.1584                 2  ...    65.275000
# 2617                       0.1472                 2  ...    65.425000
# 2618                       0.1584                 2  ...    63.466667
# 2619                       0.1687                 2  ...    66.966667
# 2620                       0.1687                 2  ...    67.300000
#
#       avg_copd  avg_smoking  avg_depression  avg_diabetes  avg_ghlth  \
# 0     8.821875    19.321875       20.575000     12.378125  20.303125
# 1     7.067442    16.818605       20.256589     10.819380  18.208527
# 2     9.215094    16.686792       18.324528     12.662264  19.600000
# 3     4.977528    15.800000       20.562921      9.938202  16.479775
# 4     7.030357    16.417857       21.016071      9.007143  17.764286
# ...        ...          ...             ...           ...        ...
# 2616  5.983333    18.658333       19.225000      7.541667  15.700000
# 2617  4.425000    12.175000       16.825000      6.025000  10.950000
# 2618  7.200000    20.266667       19.833333      8.066667  17.100000
# 2619  8.033333    18.133333       18.000000     10.433333  18.466667
# 2620  8.000000    19.250000       18.100000      9.500000  17.050000
#
#         avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0     31.053125  16.381250    40.696875  38.543750
# 1     27.695349  14.471318    33.551938  36.662791
# 2     27.286792  13.303774    34.924528  33.426415
# 3     20.893820  13.581461    28.410112  37.917978
# 4     24.160714  17.630357    30.223214  35.637500
# ...         ...        ...          ...        ...
# 2616  24.366667  13.900000    33.166667  35.808333
# 2617  17.500000  10.875000    21.975000  27.325000
# 2618  27.466667  14.533333    30.133333  36.333333
# 2619  26.600000  13.033333    28.933333  31.466667
# 2620  27.100000  13.350000    33.850000  33.700000
#
# [2398 rows x 28 columns]

# %%
df_new.dtypes
# Out:
# the_number_of_providers                                             int64
# the_average_supply_level                                          float64
# fips_code                                                           int64
# social_vulnerability_index_svi                                    float64
# cvac_level_of_concern_for_vaccination_rollout                     float64
# percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21    float64
# estimated_hesitant                                                float64
# estimated_hesitant_or_unsure                                      float64
# estimated_strongly_hesitant                                       float64
# masks_order_code                                                    int64
# completeness_pct                                                  float64
# metro_status                                                        int32
# general_gb_order_code                                               int64
# general_or_under_6ft_bans_gatherings_over                           int32
# stay_at_home_order_code                                             int64
# community_transmission_level                                        int32
# avg_asthma                                                        float64
# avg_chd                                                           float64
# avg_checkup                                                       float64
# avg_copd                                                          float64
# avg_smoking                                                       float64
# avg_depression                                                    float64
# avg_diabetes                                                      float64
# avg_ghlth                                                         float64
# avg_lpa                                                           float64
# avg_mhlth                                                         float64
# avg_obesity                                                       float64
# avg_sleep                                                         float64
# dtype: object

# %% [markdown]
# # Define Features Set and Three Targets:

# %%
# define features set used for all three targets
X = df_new.copy()
X = X.drop(['estimated_hesitant', 'estimated_hesitant_or_unsure', 'estimated_strongly_hesitant'], axis=1)
X.head()
# Out:
#    the_number_of_providers  the_average_supply_level  fips_code  \
# 0                      195                  0.333333      10001
# 1                      638                  0.194357      10003
# 2                      295                  0.196610      10005
# 3                      678                  0.244838      11001
# 4                      345                  0.382609      12001
#
#    social_vulnerability_index_svi  \
# 0                            0.73
# 1                            0.38
# 2                            0.40
# 3                            0.60
# 4                            0.47
#
#    cvac_level_of_concern_for_vaccination_rollout  \
# 0                                           0.32
# 1                                           0.16
# 2                                           0.12
# 3                                           0.17
# 4                                           0.63
#
#    percent_adults_fully_vaccinated_against_covid_19_as_of_6_10_21  \
# 0                                              0.435
# 1                                              0.552
# 2                                              0.569
# 3                                              0.546
# 4                                              0.547
#
#    masks_order_code  completeness_pct  metro_status  general_gb_order_code  \
# 0                 2              96.1             0                      1
# 1                 2              96.1             0                      1
# 2                 2              96.1             0                      1
# 3                 2              94.6             0                      1
# 4                 2              98.7             0                      1
#
#    ...  avg_checkup  avg_copd  avg_smoking  avg_depression  avg_diabetes  \
# 0  ...    80.593750  8.821875    19.321875       20.575000     12.378125
# 1  ...    79.198450  7.067442    16.818605       20.256589     10.819380
# 2  ...    81.164151  9.215094    16.686792       18.324528     12.662264
# 3  ...    79.094944  4.977528    15.800000       20.562921      9.938202
# 4  ...    76.055357  7.030357    16.417857       21.016071      9.007143
#
#    avg_ghlth    avg_lpa  avg_mhlth  avg_obesity  avg_sleep
# 0  20.303125  31.053125  16.381250    40.696875  38.543750
# 1  18.208527  27.695349  14.471318    33.551938  36.662791
# 2  19.600000  27.286792  13.303774    34.924528  33.426415
# 3  16.479775  20.893820  13.581461    28.410112  37.917978
# 4  17.764286  24.160714  17.630357    30.223214  35.637500
#
# [5 rows x 25 columns]

# %%
# set target for each model
hes_y = df_new['estimated_hesitant']

hes_unsure_y = df_new['estimated_hesitant_or_unsure']

strg_hes_y = df_new['estimated_strongly_hesitant']

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Hesitant

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    hes_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1798, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.14305031, 0.11499829, 0.15149326, 0.13814763, 0.1186837 ,
#        0.15452055, 0.16696081, 0.04245067, 0.1180571 , 0.09961323,
#        0.11381692, 0.1360351 , 0.05144251, 0.12759564, 0.18002179,
#        0.08941326, 0.13071495, 0.14549372, 0.15043144, 0.05509023,
#        0.15856255, 0.11781001, 0.10826957, 0.1553233 , 0.14542552,
#        0.04199855, 0.18213661, 0.13024353, 0.14065901, 0.10236505,
#        0.17181415, 0.08480559, 0.06097526, 0.18119725, 0.1540648 ,
#        0.12096328, 0.181639  , 0.16325602, 0.1579272 , 0.10454659,
#        0.12042609, 0.10930471, 0.11119827, 0.14545962, 0.14850641,
#        0.16990566, 0.13817358, 0.07533468, 0.15529719, 0.11341588,
#        0.16728663, 0.16371292, 0.11878779, 0.12131308, 0.15776995,
#        0.09224539, 0.10487212, 0.16234551, 0.10874858, 0.14457576,
#        0.09149354, 0.15689987, 0.07565046, 0.15279436, 0.13370564,
#        0.14125195, 0.04968354, 0.1245885 , 0.10953373, 0.14880591,
#        0.08447894, 0.11551826, 0.14079912, 0.16093292, 0.14539416,
#        0.16273577, 0.13630282, 0.12220095, 0.13220398, 0.12631612,
#        0.13841851, 0.11143924, 0.14112472, 0.1614423 , 0.12007646,
#        0.1344754 , 0.11973342, 0.11520116, 0.12984684, 0.15896726,
#        0.11585551, 0.13228709, 0.16817484, 0.11134261, 0.12731752,
#        0.09458388, 0.13388924, 0.08086607, 0.18404443, 0.12052851,
#        0.142924  , 0.13169446, 0.12159138, 0.1734203 , 0.15396978,
#        0.10218997, 0.12023503, 0.12029386, 0.12035917, 0.1268471 ,
#        0.17409345, 0.14565939, 0.11869323, 0.03464433, 0.16566823,
#        0.15590188, 0.15559488, 0.17424436, 0.13146919, 0.15958158,
#        0.14851999, 0.12236413, 0.17189056, 0.1309466 , 0.07913141,
#        0.1114774 , 0.17476122, 0.12696769, 0.06518109, 0.17705213,
#        0.08357047, 0.16909203, 0.10078326, 0.12515124, 0.0754054 ,
#        0.07041254, 0.14423789, 0.13973842, 0.1276626 , 0.1360718 ,
#        0.16375375, 0.13028239, 0.14652002, 0.17054197, 0.16388924,
#        0.09112127, 0.07058946, 0.11455474, 0.08693362, 0.130329  ,
#        0.15956658, 0.16616927, 0.10159993, 0.11732662, 0.14065442,
#        0.10904754, 0.13935701, 0.1693645 , 0.14526522, 0.06500447,
#        0.15906971, 0.17059081, 0.14788271, 0.15770395, 0.15802493,
#        0.18698888, 0.13529159, 0.1544492 , 0.12605581, 0.08599887,
#        0.13116236, 0.16414631, 0.12967586, 0.17117785, 0.15305624,
#        0.17064077, 0.09061118, 0.15648192, 0.17689654, 0.15265042,
#        0.15222096, 0.15068646, 0.09849465, 0.1379965 , 0.01402292])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Hesitant\n")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Hesitant
#
# R2 Score : 0.5820480931865175

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Hesitant or Unsure

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    hes_unsure_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1798, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.19590684, 0.16351639, 0.22357303, 0.19855687, 0.18142977,
#        0.19940895, 0.23279539, 0.08460727, 0.18329692, 0.15877247,
#        0.16703397, 0.19106675, 0.10924171, 0.21802594, 0.24692212,
#        0.17086385, 0.20005733, 0.20706072, 0.20931253, 0.09013502,
#        0.22798241, 0.17252182, 0.16910852, 0.23579935, 0.21417395,
#        0.07977344, 0.26141777, 0.19010764, 0.21214058, 0.18949656,
#        0.23259653, 0.12796816, 0.11722503, 0.25011208, 0.21789208,
#        0.17903902, 0.24234612, 0.22926311, 0.2075921 , 0.1542308 ,
#        0.24232492, 0.16604945, 0.18191154, 0.18479864, 0.25558257,
#        0.20979705, 0.18813596, 0.21605006, 0.2230982 , 0.15198086,
#        0.22258092, 0.13943735, 0.25029549, 0.1515511 , 0.19303267,
#        0.17625451, 0.15375876, 0.27248862, 0.23002591, 0.18997151,
#        0.1831739 , 0.16197276, 0.15628621, 0.18716052, 0.18937796,
#        0.22658362, 0.23141586, 0.15948171, 0.18903807, 0.19878874,
#        0.14363204, 0.18555583, 0.21009223, 0.22893444, 0.21196888,
#        0.22430649, 0.20110271, 0.16507518, 0.19302556, 0.17475574,
#        0.19549572, 0.15664938, 0.19973102, 0.2206555 , 0.18129962,
#        0.19599807, 0.15026908, 0.17626177, 0.18117328, 0.22743579,
#        0.16618173, 0.18828874, 0.23410899, 0.15866298, 0.16786181,
#        0.14224456, 0.20121123, 0.13215205, 0.27246293, 0.17876782,
#        0.2281119 , 0.18146929, 0.17973454, 0.24101399, 0.22141523,
#        0.15837347, 0.17242832, 0.18831088, 0.17960787, 0.19350074,
#        0.24914743, 0.21413097, 0.16174919, 0.07354776, 0.23414282,
#        0.24838062, 0.21738034, 0.24522704, 0.19084834, 0.22227395,
#        0.20666936, 0.18812525, 0.24391479, 0.18450575, 0.13510152,
#        0.15294203, 0.23142931, 0.17974763, 0.12220817, 0.23889756,
#        0.12379734, 0.23956492, 0.16995758, 0.18030523, 0.11604896,
#        0.12886715, 0.20666096, 0.18531373, 0.18728432, 0.19449147,
#        0.22965177, 0.18264467, 0.21545904, 0.23980485, 0.24359165,
#        0.11892069, 0.10817699, 0.16024705, 0.14466901, 0.18427594,
#        0.25533326, 0.2290867 , 0.16646964, 0.18253523, 0.21006756,
#        0.16912693, 0.20581443, 0.24514893, 0.19898024, 0.12164214,
#        0.22843966, 0.23708297, 0.2086731 , 0.2084375 , 0.21287698,
#        0.25321601, 0.21639765, 0.25410436, 0.18767551, 0.13881333,
#        0.20414323, 0.22674463, 0.17038434, 0.24408877, 0.21919246,
#        0.24309795, 0.15576101, 0.21756809, 0.24451261, 0.20440503,
#        0.21796142, 0.20577256, 0.1799184 , 0.22406958, 0.05398556])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Hesitant or Unsure\n")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Hesitant or Unsure
#
# R2 Score : 0.6040122184333528

# %% [markdown]
# # Train, Test, Evaluate Model
# ##  Target: Estimated Strongly Hesitant

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    strg_hes_y, 
                                                    random_state=1)
X_train.shape
# Out:
# (1798, 25)

# %%
# fit the model
from sklearn.linear_model import LinearRegression
classifier = LinearRegression().fit(X_train, y_train)

# %%
# predict with test data
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0.09581188, 0.06654623, 0.0942894 , 0.09402692, 0.07786338,
#        0.10747339, 0.11033275, 0.02657754, 0.07486617, 0.06812314,
#        0.07703884, 0.08653483, 0.02942339, 0.07714062, 0.1265814 ,
#        0.05565514, 0.08451224, 0.09249492, 0.09970338, 0.04163832,
#        0.10304831, 0.07512068, 0.07299756, 0.09786017, 0.09483343,
#        0.02649655, 0.12469242, 0.08216473, 0.09425928, 0.06356294,
#        0.11803268, 0.06272266, 0.03845415, 0.12153094, 0.09802713,
#        0.0757341 , 0.12327912, 0.11715699, 0.11015197, 0.06382105,
#        0.07122209, 0.06895263, 0.07421377, 0.09530173, 0.09416809,
#        0.11482024, 0.08691292, 0.05103455, 0.10519417, 0.06852963,
#        0.1115099 , 0.10717044, 0.07288536, 0.08012986, 0.10373525,
#        0.0617999 , 0.06147389, 0.10907918, 0.07165743, 0.0887568 ,
#        0.05694792, 0.10214569, 0.0514739 , 0.09917522, 0.08968793,
#        0.09122756, 0.0356225 , 0.0800698 , 0.06654975, 0.0978494 ,
#        0.10262106, 0.1076242 , 0.08929899, 0.09644249, 0.09829673,
#        0.08957025, 0.10351718, 0.10701092, 0.08166218, 0.13155442,
#        0.09183503, 0.02791706, 0.06668604, 0.08642651, 0.0953553 ,
#        0.10241447, 0.08133821, 0.08030819, 0.07900084, 0.04425464,
#        0.05949988, 0.09345602, 0.06385064, 0.06216536, 0.04099206,
#        0.07839422, 0.05082116, 0.09257123, 0.111985  , 0.09753235,
#        0.08275744, 0.09233563, 0.09585203, 0.07356642, 0.1090202 ,
#        0.10734195, 0.06439328, 0.10026663, 0.06967681, 0.08149877,
#        0.05123766, 0.05995515, 0.08533169, 0.01531726, 0.08949365,
#        0.10515989, 0.116377  , 0.08263001, 0.09349685, 0.12499543,
#        0.08529478, 0.08221772, 0.11492643, 0.07427775, 0.10598976,
#        0.06484648, 0.07604944, 0.09950105, 0.10917243, 0.0657296 ,
#        0.11454012, 0.07357221, 0.10532429, 0.12756889, 0.07518491,
#        0.09910032, 0.11281913, 0.08449363, 0.10078858, 0.0948604 ,
#        0.09809694, 0.06263667, 0.10969903, 0.01247227, 0.10720531,
#        0.10847045, 0.07994149, 0.05024071, 0.10682799, 0.08796748,
#        0.1329391 , 0.08655378, 0.11181751, 0.10041458, 0.09822722,
#        0.10194194, 0.08915458, 0.06861154, 0.12871882, 0.07784033,
#        0.05754492, 0.07143606, 0.08871863, 0.05096397, 0.04982586,
#        0.0979641 , 0.07925858, 0.07213726, 0.11423702, 0.06091735,
#        0.04645056, 0.07530411, 0.08873757, 0.07809221, 0.08353464,
#        0.06341189, 0.0904828 , 0.11980838, 0.04666052, 0.11080071,
#        0.09120981, 0.11106363, 0.1005244 , 0.07404151, 0.07874031,
#        0.04855079, 0.06401611, 0.11575292, 0.09208039, 0.06453921,
#        0.12132954, 0.06801592, 0.06980511, 0.06919074, 0.10250255,
#        0.07040916, 0.01499394, 0.08583937, 0.08852172, 0.1349974 ,
#        0.08493067, 0.10128565, 0.10854681, 0.10039012, 0.08865705,
#        0.08403067, 0.06906557, 0.11390864, 0.07751011, 0.08033627,
#        0.11723212, 0.09089759, 0.05444959, 0.08431515, 0.09352133,
#        0.06051979, 0.0827937 , 0.05813287, 0.08158096, 0.05306622,
#        0.0654762 , 0.1330772 , 0.07879217, 0.07139559, 0.09662267,
#        0.07789742, 0.03981396, 0.08119559, 0.0533084 , 0.11890537,
#        0.06880842, 0.08149171, 0.11964888, 0.08835825, 0.07379752,
#        0.1177786 , 0.08867679, 0.08975378, 0.06518915, 0.13564175,
#        0.07398431, 0.08564947, 0.07139561, 0.09901121, 0.06103121,
#        0.03691393, 0.09443633, 0.08408504, 0.07379584, 0.05916758,
#        0.08656731, 0.07091536, 0.09099047, 0.11726111, 0.04506897,
#        0.08476294, 0.08594691, 0.12051032, 0.10553768, 0.0590278 ,
#        0.08994526, 0.08993337, 0.0888371 , 0.0640382 , 0.09866899,
#        0.07773934, 0.09855199, 0.0818286 , 0.10650808, 0.09933965,
#        0.09854962, 0.12016636, 0.04902536, 0.10186539, 0.06477289,
#        0.06909764, 0.06827744, 0.07812163, 0.08327777, 0.08721912,
#        0.08073137, 0.10987172, 0.05644818, 0.07980369, 0.07125059,
#        0.10365835, 0.06184094, 0.09014265, 0.08035413, 0.07253963,
#        0.11447173, 0.09280337, 0.0754053 , 0.06784558, 0.08496502,
#        0.0687386 , 0.11763462, 0.07163048, 0.04162114, 0.084537  ,
#        0.09572812, 0.07584638, 0.06481992, 0.08592098, 0.07974216,
#        0.10333368, 0.09514564, 0.0946898 , 0.07087952, 0.13285278,
#        0.10338716, 0.11918016, 0.07819386, 0.0778109 , 0.06403093,
#        0.08220923, 0.13253986, 0.09178512, 0.08847149, 0.09669571,
#        0.05490028, 0.10563971, 0.1157077 , 0.0443762 , 0.10300123,
#        0.10077553, 0.12008259, 0.07119074, 0.08543637, 0.10773013,
#        0.09405694, 0.11875435, 0.07210917, 0.05292929, 0.07684072,
#        0.08704728, 0.11262609, 0.10905794, 0.13905041, 0.11958668,
#        0.08425023, 0.08483957, 0.13843002, 0.07828089, 0.0695592 ,
#        0.10098311, 0.10639601, 0.10854525, 0.08948056, 0.08507703,
#        0.05588388, 0.09981784, 0.08543496, 0.08236828, 0.08941947,
#        0.0712351 , 0.1106035 , 0.05117462, 0.09986066, 0.11689467,
#        0.08375531, 0.07244008, 0.0430922 , 0.08189721, 0.04213346,
#        0.07660568, 0.11158959, 0.0895378 , 0.07852435, 0.06978783,
#        0.05247666, 0.07849712, 0.08923571, 0.09926657, 0.07932526,
#        0.05644686, 0.06757511, 0.07707569, 0.06665056, 0.05646651,
#        0.10706277, 0.09497562, 0.09639062, 0.0941754 , 0.09622662,
#        0.04893076, 0.09034677, 0.10682195, 0.07357193, 0.03273263,
#        0.07349315, 0.11127423, 0.07917454, 0.03575718, 0.07263269,
#        0.12954419, 0.06084122, 0.11740756, 0.1255756 , 0.10529195,
#        0.06601239, 0.08406202, 0.13378539, 0.08737531, 0.06632452,
#        0.08505966, 0.10322393, 0.05956265, 0.08497694, 0.0543261 ,
#        0.12216094, 0.07785476, 0.02951814, 0.03672153, 0.0192425 ,
#        0.09952641, 0.09030246, 0.09574124, 0.08716912, 0.11308187,
#        0.04698905, 0.11204725, 0.12003346, 0.06512518, 0.090329  ,
#        0.09387276, 0.06769066, 0.07012772, 0.05798144, 0.09308715,
#        0.09585966, 0.0998565 , 0.09589244, 0.07046585, 0.05327978,
#        0.07959805, 0.08154995, 0.08895327, 0.12893377, 0.06432622,
#        0.10334993, 0.09802153, 0.08851543, 0.08667713, 0.10848333,
#        0.06442778, 0.11890484, 0.07207827, 0.07418272, 0.05983348,
#        0.12968154, 0.08912987, 0.10453108, 0.10710658, 0.12632876,
#        0.12359017, 0.07371297, 0.07707867, 0.07503916, 0.12406902,
#        0.10464931, 0.07969804, 0.10109059, 0.11624672, 0.06576919,
#        0.10139166, 0.05683972, 0.12104497, 0.07057105, 0.0821805 ,
#        0.08016383, 0.06980371, 0.12002519, 0.11541449, 0.08404269,
#        0.08390866, 0.06562232, 0.06154442, 0.0809329 , 0.09274717,
#        0.10577819, 0.09904431, 0.06263919, 0.07487763, 0.06997805,
#        0.05366   , 0.07769391, 0.08961995, 0.10401658, 0.09868063,
#        0.10796861, 0.08983231, 0.08175594, 0.08410733, 0.08857237,
#        0.08599767, 0.07435912, 0.08533539, 0.11023692, 0.0754374 ,
#        0.08694321, 0.06968918, 0.07902378, 0.07801752, 0.10037491,
#        0.06953074, 0.08342337, 0.11195074, 0.06561756, 0.07668498,
#        0.05327645, 0.09155241, 0.05327755, 0.1235132 , 0.07713747,
#        0.09288188, 0.0849542 , 0.07542788, 0.11558611, 0.09907556,
#        0.05955634, 0.07172104, 0.07160182, 0.08424489, 0.08484033,
#        0.11830039, 0.09312208, 0.07602803, 0.02076325, 0.1107183 ,
#        0.09947808, 0.10094608, 0.11719308, 0.07917302, 0.09790775,
#        0.09255147, 0.07912234, 0.11768862, 0.08967066, 0.04643146,
#        0.06765885, 0.11585197, 0.08984137, 0.03947625, 0.12027465,
#        0.06169594, 0.11116497, 0.0672518 , 0.07560754, 0.05923409,
#        0.04588627, 0.09434122, 0.08891304, 0.08448678, 0.08714041,
#        0.10585412, 0.0824884 , 0.09325345, 0.11530567, 0.10656512,
#        0.05573498, 0.04028909, 0.07836693, 0.06384616, 0.08553619,
#        0.10455193, 0.1120819 , 0.06961708, 0.08208758, 0.09013356,
#        0.07048237, 0.09663595, 0.10585251, 0.10144048, 0.04246503,
#        0.10521639, 0.11552907, 0.10335457, 0.10000133, 0.10520081,
#        0.12432057, 0.08967343, 0.09857998, 0.08158979, 0.05868494,
#        0.08091028, 0.11332049, 0.08667817, 0.1090494 , 0.09850933,
#        0.11462679, 0.0611155 , 0.10954851, 0.12306928, 0.09956805,
#        0.0994605 , 0.09652945, 0.05228071, 0.0845306 , 0.00786561])

# %%
# Model Evaluation:
from sklearn.metrics import r2_score
print("\n*****Linear Regression Model Evaluation*****")
print("---------------------------------------")
print("Target Predicted : Estimated Strongly Hesitant")
print(f"R2 Score : {r2_score(y_test, y_pred)}")
# Out:
# *****Linear Regression Model Evaluation*****
# ---------------------------------------
# Target Predicted : Estimated Strongly Hesitant
# R2 Score : 0.5657270730273718
